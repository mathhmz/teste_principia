# %%
import pandas as pd
import json
import re
from datetime import datetime
import requests
import os
from typing import Any

dados = "dados.xlsx"
sistema = "sistema.xlsx"

class DataService: 
    def __init__(self, dados_path, sistema_path) -> None: 
        self.dados_path =  dados_path
        self.sistema_path = sistema_path
        
    def get_data(self) -> list:
        
        dfs = []
        
        sources = [self.dados_path, self.sistema_path]
        for source in sources:
            file_name, file_extension = os.path.splitext(source)
            
            try: 
                if file_name == "dados":
                    df_dados = pd.read_excel(source)
                    dfs.append(df_dados)
                else:
                    df_sistema = pd.read_excel(source)
                    dfs.append(df_sistema)
            except TypeError:
                print(f"{file_extension} is not a valid extension.")
                
        return dfs
    
    def __call__(self) -> list:
        return self.get_data()
    
class RowValidator:
    def __init__(self, data):
        self.data = data
        
    def validate_cpf(self):
        cpf = self.data.get('cpf')
        cpf = re.sub(r'\D', '', cpf)
        if len(cpf) != 11 or cpf == cpf[0] * 11:
            return False
        for i in range(9, 11):
            cpf_sum = sum(int(cpf[num]) * (i + 1 - num) for num in range(i))
            key_value = (cpf_sum * 10 % 11) % 10
            if key_value != int(cpf[i]):
                return False
        return True

    def validate_name(self):
        name = self.data.get('nome')
        return len(name.split()) >= 2

    def validate_birthday_and_age(self):
        birthday = self.data.get('data_nasc')
        today = datetime.today()
        
        if isinstance(birthday, datetime):
            birth_date = birthday
        else:
            formats = ['%Y-%m-%d', '%d/%m/%Y']
            birth_date = None
            for valid_format in formats:
                try:
                    birth_date = datetime.strptime(birthday, valid_format)
                    break
                except ValueError:
                    continue
            
            if birth_date is None:
                return False 

        age = (today - birth_date).days / 365.25
        return age >= 17

    def validate_email(self):
        email = self.data.get('email', "")
        regex = r'^\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
        return re.match(regex, email) is not None

    def validate_phone(self):
        phone_number = self.data.get('celular')
        regex = r'^\([1-9]{2}\) (?:[2-8]|9[0-9])[0-9]{3}\-[0-9]{4}$'  
        return re.match(regex, phone_number) is not None

    def validate_cep(self):
        cep = self.data.get('cep')
        url = f"https://viacep.com.br/ws/{cep}/json/"
        response = requests.get(url)
        if response.status_code == 200:
            dados_cep = response.json()
            if "erro" not in dados_cep:
                return True, dados_cep
        return False, None

    def validar_cliente(self):
        resultado = {
            'cpf_validation': self.validate_cpf(),
            'name_validation': self.validate_name(),
            'birthdate_and_age_validation': self.validate_birthday_and_age(),
            'email_validation': self.validate_email(),
            'phone_validation': self.validate_phone(),
            'cep_validation': self.validate_cep()[0]
        }
        return resultado

    def pipeline(self):
        validacoes = self.validar_cliente()
        return validacoes

    def __call__(self): 
        return self.pipeline()

class ValidatorService:
    def __init__(self,dataframe) -> None:
        self.dataframe = dataframe
    
    def normalize_dataframe(self) -> pd.DataFrame:
        columns = {"NOME" : "nome",
            "CPF" : "cpf",
            "Data de Nascimento" : "data_nasc",
            "Email" : "email",
            "CEP" : "cep",
            "Endereço" : "endereco",
            "Numero" : "numero",
            "Bairro" : "bairro",
            "Cidade" : "cidade",
            "Estado" : "estado",
            "Telefone" : "celular",
            "RA" : "ra",
            "Curso" : "curso",
            "Faculdade" : "faculdade"
            }
            
        normalized_dataframe = self.dataframe.rename(columns = columns)
        return normalized_dataframe
    
    def create_valid_and_detached_list(self, dataframe: pd.DataFrame) -> Any:
        valid_list = []
        detached_list = []

        for _, line in dataframe.iterrows():
            l = line.to_dict()
            
            row_validator = RowValidator(l)
            
            is_valid = row_validator()
            
            if all(condition == True for condition in is_valid.values()):
                valid_list.append(l)

            else: 
                detach_reasons = [key for key, value in is_valid.items() if not value]
                l["detach_reason"] = detach_reasons
                detached_list.append(l)
                
        print(valid_list)
        print(detached_list)
                
        complete_lists = [valid_list, detached_list]
                
        return complete_lists
    
    def pipeline(self) -> Any:
        df = self.normalize_dataframe()
        complete_lists = self.create_valid_and_detached_list(dataframe= df)
        print(complete_lists)
        return complete_lists
    
    def __call__(self) -> Any:
        return self.pipeline()
        
class UpdateOrDuplicatedChecker:
    def __init__(self, lists : list, df_system : pd.DataFrame) -> None:
        self.valid, self.detached = lists
        self.df_system = df_system
    
    def check_update_needed(self):
        print(self.valid)
        print(self.detached)
        df_detached = pd.DataFrame(self.detached)
        df_valid = pd.DataFrame(self.valid)
        df_system = self.df_system.copy()
        df_valid['cpf'] = df_valid['cpf'].str.replace(r'\D', '', regex=True)
        df_system['cpf'] = df_system['cpf'].str.replace(r'\D', '', regex=True)
        
        common_cpf = set(df_valid['cpf']).intersection(set(df_system['cpf']))
        
        removed_from_valid = []
        
        for cpf in common_cpf:
            df_valid_row = df_valid[df_valid['cpf'] == cpf].drop(columns='cpf').reset_index(drop = True)
            df_system_row = df_system[df_system['cpf'] == cpf].drop(columns='cpf').reset_index(drop = True)
            
            common_cols = df_valid_row.columns.intersection(df_system_row.columns)
            
            print(common_cols)
            
            df_valid_row_common = df_valid_row[common_cols]
            df_system_row_common = df_system_row[common_cols]
            
            print(df_valid_row_common)
            print(df_system_row_common)
            
            if df_valid_row_common.equals(df_system_row_common):
                valid_row_dict = df_valid[df_valid['cpf'] == cpf].to_dict('records')[0]
                valid_row_dict['detach_reason'] = ['No Update Needed']
                removed_from_valid.append(valid_row_dict)
                df_valid = df_valid[df_valid['cpf'] != cpf]

            else:
                df_valid.loc[df_valid['cpf'] == cpf, 'tipo'] = 'A'
                    
        df_detached = pd.concat([df_detached, pd.DataFrame(removed_from_valid)], ignore_index=True)
                
        df_valid.loc[~df_valid['cpf'].isin(df_system['cpf']), 'tipo'] = 'I'
        
        df_detached.reset_index(drop=True, inplace=True)
        
        return [df_valid, df_detached]
    
    def __call__(self) -> Any:
        return self.check_update_needed()

# %%
data_service = DataService(dados,sistema)

# %%
data = data_service()

# %%
validator_service = ValidatorService(dataframe = data[0])

# %%
validated_lists = validator_service()
# Out:
# [{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade' ...
# [{'nome': 'Antônia Esther Vitória Cardoso', 'cpf': '564.798.046-52', 'data_nasc': datetime.datetime(1984, 2, 6, 0, 0), 'email': 'antonia-cardoso92@suzano.com.br', 'cep': '69041-380', 'endereco': 'Rua Praia Farol da Barra', 'numero': 935, 'bairro': 'Tarumã', 'cidade': 'Manaus', 'estado': 'AM', 'celular': '(92) 98772-3758', 'ra': 1077822, 'curso': 'Direito', 'faculdade': 'UNICAMP', 'detach_reason': ['cpf_validation']}, {'nome': 'Mariane Maya Stella Novaes', 'cpf': '972.063.648-73', 'data_nasc': datetime.datetime(1996, 3, 13, 0, 0), 'email': 'mariane_novaes@pq.cnpq.br', 'cep': '40081-320', 'endereco': 'Travessa Hugo Wilson', 'numero': 431, 'bairro': 'Vitória', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99779-9889', 'ra': 649062, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Luzia Flávia Bernardes', 'cpf': '669.222.518-3', 'data_nasc': '16/03/1968', 'email': 'luziaflaviabernardes@gimail.com', 'cep': '49080-230', 'endereco': 'Praça Franklin Delano Roosevelt', 'numero': 789, 'bairro': 'América', 'cidade': 'Aracaju', 'estado': 'SE', 'celular': '(79) 98665-1272', 'ra': 94708, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Rosa Nair Dias', 'cpf': '48.923.212-49', 'data_nasc': datetime.datetime(2004, 5, 7, 0, 0), 'email': 'rosa-dias84@myself.com', 'cep': '58030-070', 'endereco': 'Avenida Santa Catarina', 'numero': 690, 'bairro': 'Estados', 'cidade': 'João Pessoa', 'estado': 'PB', 'celular': '(83) 99964-8228', 'ra': 373373, 'curso': 'Engenharia', 'faculdade': 'UFBA', 'detach_reason': ['cpf_validation']}]
# [[{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade ...

# %%
validated_lists[0]
# Out:
# [{'nome': 'Ana Sarah Luna Nunes',
#   'cpf': '145.388.540-42',
#   'data_nasc': datetime.datetime(1985, 6, 7, 0, 0),
#   'email': 'ana_nunes@live.dk',
#   'cep': '78028-505',
#   'endereco': 'Avenida Florianópolis',
#   'numero': 807,
#   'bairro': 'Cidade Verde',
#   'cidade': 'Cuiabá',
#   'estado': 'MT',
#   'celular': '(65) 98939-8957',
#   'ra': 274405,
#   'curso': 'Adiministração ',
#   'faculdade': 'USP'},
#  {'nome': 'Benedita Raimunda Lorena Rezende',
#   'cpf': '746.863. 209-09',
#   'data_nasc': '14/02/2001',
#   'email': 'benedita_raimunda_rezende@eletrotex.com.br',
#   'cep': '87309-710',
#   'endereco': 'Rua Nelson Behrens',
#   'numero': 382,
#   'bairro': 'Jardim Silvana',
#   'cidade': 'Campo Mourão',
#   'estado': 'PR',
#   'celular': '(44) 99920-1842',
#   'ra': 720462,
#   'curso': 'Física',
#   'faculdade': 'UFBA'},
#  {'nome': 'Stella Isabelle da Conceição',
#   'cpf': '914.506.816-03',
#   'data_nasc': datetime.datetime(1994, 3, 10, 0, 0),
#   'email': 'stella-daconceicao92@arbitral.com',
#   'cep': '11095-906',
#   'endereco': 'Rua Augusto Scaraboto, s/n',
#   'numero': 277,
#   'bairro': 'Alemoa',
#   'cidade': 'Santos',
#   'estado': 'SP',
#   'celular': '(13) 98265-8773',
#   'ra': 882979,
#   'curso': 'Adiministração ',
#   'faculdade': 'USP'},
#  {'nome': 'Fábio Julio Theo Rodrigues',
#   'cpf': '180.553.901-93',
#   'data_nasc': '08/01/1993',
#   'email': 'fabio_rodrigues@soupelli.com.br',
#   'cep': '59604-155',
#   'endereco': 'Rua Coronel Fausto',
#   'numero': 137,
#   'bairro': 'Lagoa do Mato',
#   'cidade': 'Mossoró',
#   'estado': 'RN',
#   'celular': '(84) 98606-6462',
#   'ra': 504901,
#   'curso': 'Direito',
#   'faculdade': 'UNICAMP'},
#  {'nome': 'Raquel Flávia Luzia Campos',
#   'cpf': '542.315.336-01',
#   'data_nasc': datetime.datetime(1988, 2, 8, 0, 0),
#   'email': 'raquel.flavia.campos@infortec.com.br',
#   'cep': '53650-180',
#   'endereco': 'Rua Suiça',
#   'numero': 446,
#   'bairro': 'Bela Vista',
#   'cidade': 'Igarassu',
#   'estado': 'PE',
#   'celular': '(81) 99762-2419',
#   'ra': 657179,
#   'curso': 'Biologia',
#   'faculdade': 'USP'},
#  {'nome': 'César Roberto Castro',
#   'cpf': '568.624.267-45',
#   'data_nasc': datetime.datetime(1988, 1, 9, 0, 0),
#   'email': 'cesar-castro95@vectrausinagem.com.br',
#   'cep': '86191-470',
#   'endereco': 'Rua Reinaldo Resquetti',
#   'numero': 165,
#   'bairro': 'Jardim Boa Vista',
#   'cidade': 'Cambé',
#   'estado': 'PR',
#   'celular': '(43) 99231-1491',
#   'ra': 533964,
#   'curso': 'Letras',
#   'faculdade': 'UFPR'},
#  {'nome': 'Carolina Luzia Pinto',
#   'cpf': '466.5 22.594-00',
#   'data_nasc': '16/01/1980',
#   'email': 'carolina.luzia.pinto@ceviu.com.br',
#   'cep': '09134-690',
#   'endereco': 'Rua Catitu',
#   'numero': 244,
#   'bairro': 'Cidade Recreio da Borda do Campo',
#   'cidade': 'Santo André',
#   'estado': 'SP',
#   'celular': '(11) 99533-7515',
#   'ra': 586615,
#   'curso': 'Matemática',
#   'faculdade': 'USP'},
#  {'nome': 'Gabriela Kamilly Fernandes',
#   'cpf': '672.614.581-04',
#   'data_nasc': datetime.datetime(1981, 6, 3, 0, 0),
#   'email': 'gabriela_kamilly_fernandes@compecia.com.br',
#   'cep': '41345-240',
#   'endereco': 'Caminho 17-Setor 04',
#   'numero': 605,
#   'bairro': 'Cajazeiras',
#   'cidade': 'Salvador',
#   'estado': 'BA',
#   'celular': '(71) 99524-3132',
#   'ra': 716203,
#   'curso': 'Adiministração ',
#   'faculdade': 'UFBA'},
#  {'nome': 'Juan Theo Yuri Almeida',
#   'cpf': '762.138.549-91',
#   'data_nasc': '26/05/1990',
#   'email': 'juan_theo_almeida@cppcoder.com',
#   'cep': '71591-350',
#   'endereco': 'Quadra Quadra 40',
#   'numero': 131,
#   'bairro': 'São Caetano',
#   'cidade': 'Itabuna',
#   'estado': 'BA',
#   'celular': '(61) 98970-8388',
#   'ra': 434495,
#   'curso': 'Direito',
#   'faculdade': 'UNICAMP'},
#  {'nome': 'André Gustavo Galvão',
#   'cpf': '414.020.429-06',
#   'data_nasc': '02/05/1952',
#   'email': 'andre.gustavo.galvao@torah.com.br',
#   'cep': '74993-530',
#   'endereco': 'Avenida Maria Elias Lisboa Santos',
#   'numero': 385,
#   'bairro': 'Jardim Helian',
#   'cidade': 'São Paulo',
#   'estado': 'SP',
#   'celular': '(62) 99966-5332',
#   'ra': 991884,
#   'curso': 'Direito',
#   'faculdade': 'UNICAMP'},
#  {'nome': 'Pedro Renato Thomas Sales',
#   'cpf': '583.672.210-28',
#   'data_nasc': '15/01/1993',
#   'email': 'pedro.renato.sales@rodrigofranco.com',
#   'cep': '08265-070',
#   'endereco': 'Rua Guilherme da Cruz',
#   'numero': 718,
#   'bairro': 'Parque Industrial Vice-Presidente José Alencar',
#   'cidade': 'Aparecida de Goiânia',
#   'estado': 'GO',
#   'celular': '(11) 98758-9786',
#   'ra': 133682,
#   'curso': 'Engenharia',
#   'faculdade': 'UNICAMP'},
#  {'nome': 'Gael Enrico Theo Baptista',
#   'cpf': '741.547.791-09',
#   'data_nasc': '13/03/1998',
#   'email': 'gael_baptista@mcpsolucoesgraficas.com.br',
#   'cep': '45607-148',
#   'endereco': '2ª Travessa Santo Antonio',
#   'numero': 930,
#   'bairro': 'Del Lago I (Itapoã)',
#   'cidade': 'Brasília',
#   'estado': 'DF',
#   'celular': '(73) 98528-4335',
#   'ra': 364479,
#   'curso': 'Engenharia',
#   'faculdade': 'UNICAMP'},
#  {'nome': 'Heitor Fernando Murilo Ramos',
#   'cpf': '474.010.849-61',
#   'data_nasc': datetime.datetime(2000, 1, 1, 0, 0),
#   'email': 'heitorfernandoramos@live.com.br',
#   'cep': '99042-085',
#   'endereco': 'Rua Antônio Cesar',
#   'numero': 279,
#   'bairro': 'Vera Cruz',
#   'cidade': 'Passo Fundo',
#   'estado': 'RS',
#   'celular': '(54) 98429-6580',
#   'ra': 786470,
#   'curso': 'Biologia',
#   'faculdade': 'UFRJ'},
#  {'nome': 'Elisa Rayssa Bianca Duarte',
#   'cpf': '291.730.743-90',
#   'data_nasc': '13/05/2000',
#   'email': 'elisa.rayssa.duarte@powerblade.com.br',
#   'cep': '79015-370',
#   'endereco': 'Rua Luíz Roncolatto',
#   'numero': 470,
#   'bairro': 'Jardim Presidente',
#   'cidade': 'Campo Grande',
#   'estado': 'MS',
#   'celular': '(67) 98591-8693',
#   'ra': 141017,
#   'curso': 'Economia',
#   'faculdade': 'UFRJ'},
#  {'nome': 'Bruno Anderson Enzo da Mata',
#   'cpf': '040.122.721-95',
#   'data_nasc': '04/02/1973',
#   'email': 'bruno_damata@aerobravo.com.br',
#   'cep': '64052-150',
#   'endereco': 'Rua Coronel Belisário da Cunha',
#   'numero': 656,
#   'bairro': 'São Cristóvão',
#   'cidade': 'Teresina',
#   'estado': 'PI',
#   'celular': '(86) 98316-2103',
#   'ra': 780593,
#   'curso': 'Direito',
#   'faculdade': 'UFRJ'},
#  {'nome': 'Eliane Sarah Silveira',
#   'cpf': '465.479.013-60',
#   'data_nasc': '21/01/1982',
#   'email': 'elianesarahsilveira@comdados.com',
#   'cep': '61608-255',
#   'endereco': 'Rua Cacique Alberto',
#   'numero': 706,
#   'bairro': 'Parque Soledade',
#   'cidade': 'Caucaia',
#   'estado': 'CE',
#   'celular': '(85) 99483-3659',
#   'ra': 703193,
#   'curso': 'Direito',
#   'faculdade': 'UFRJ'},
#  {'nome': 'Stella Isabelle da Conceição',
#   'cpf': '914.506.816-03',
#   'data_nasc': datetime.datetime(1994, 3, 10, 0, 0),
#   'email': 'stella-daconceicao92@arbitral.com',
#   'cep': '11095-906',
#   'endereco': 'Rua Augusto Scaraboto, s/n',
#   'numero': 277,
#   'bairro': 'Alemoa',
#   'cidade': 'Santos',
#   'estado': 'SP',
#   'celular': '(13) 98265-8773',
#   'ra': 882979,
#   'curso': 'Adiministração ',
#   'faculdade': 'USP'}]

# %%
update_or_duplicate = UpdateOrDuplicatedChecker(validated_lists, data[1])

# %%
lists = update_or_duplicate()
# Out:
# [{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade' ...
# [{'nome': 'Antônia Esther Vitória Cardoso', 'cpf': '564.798.046-52', 'data_nasc': datetime.datetime(1984, 2, 6, 0, 0), 'email': 'antonia-cardoso92@suzano.com.br', 'cep': '69041-380', 'endereco': 'Rua Praia Farol da Barra', 'numero': 935, 'bairro': 'Tarumã', 'cidade': 'Manaus', 'estado': 'AM', 'celular': '(92) 98772-3758', 'ra': 1077822, 'curso': 'Direito', 'faculdade': 'UNICAMP', 'detach_reason': ['cpf_validation']}, {'nome': 'Mariane Maya Stella Novaes', 'cpf': '972.063.648-73', 'data_nasc': datetime.datetime(1996, 3, 13, 0, 0), 'email': 'mariane_novaes@pq.cnpq.br', 'cep': '40081-320', 'endereco': 'Travessa Hugo Wilson', 'numero': 431, 'bairro': 'Vitória', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99779-9889', 'ra': 649062, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Luzia Flávia Bernardes', 'cpf': '669.222.518-3', 'data_nasc': '16/03/1968', 'email': 'luziaflaviabernardes@gimail.com', 'cep': '49080-230', 'endereco': 'Praça Franklin Delano Roosevelt', 'numero': 789, 'bairro': 'América', 'cidade': 'Aracaju', 'estado': 'SE', 'celular': '(79) 98665-1272', 'ra': 94708, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Rosa Nair Dias', 'cpf': '48.923.212-49', 'data_nasc': datetime.datetime(2004, 5, 7, 0, 0), 'email': 'rosa-dias84@myself.com', 'cep': '58030-070', 'endereco': 'Avenida Santa Catarina', 'numero': 690, 'bairro': 'Estados', 'cidade': 'João Pessoa', 'estado': 'PB', 'celular': '(83) 99964-8228', 'ra': 373373, 'curso': 'Engenharia', 'faculdade': 'UFBA', 'detach_reason': ['cpf_validation']}]
# Index(['nome', 'data_nasc', 'email', 'cep', 'endereco', 'numero', 'bairro',
#        'cidade', 'estado', 'celular'],
#       dtype='object')
#                    nome            data_nasc  \
# 0  César Roberto Castro  1988-01-09 00:00:00
#
#                                   email        cep                endereco  \
# 0  cesar-castro95@vectrausinagem.com.br  86191-470  Rua Reinaldo Resquetti
#
#    numero            bairro cidade estado          celular
# 0     165  Jardim Boa Vista  Cambé     PR  (43) 99231-1491
#                    nome            data_nasc  \
# 0  César Roberto Castro  1988-01-09 00:00:00
#
#                                   email        cep                endereco  \
# 0  cesar-castro95@vectrausinagem.com.br  86191-470  Rua Reinaldo Resquetti
#
#    numero            bairro cidade estado          celular
# 0     165  Jardim Boa Vista  Cambé     PR  (43) 99231-1491

# %%
lists[1].to_excel("dados_descartados.xlsx")

# %%
import re
from datetime import datetime

def transformar_em_json(df):
    json_list = []
    for _, row in df.iterrows():
        agrupador = row['faculdade'].lower()  
        ddd, telefone = row['celular'][1:3], row['celular'][5:].replace('-', '')
        
        if isinstance(row['data_nasc'], datetime):
            data_nascimento = row['data_nasc'].strftime('%d/%m/%Y')
        else:
            data_nascimento = row['data_nasc']
        
        json_obj = {
            "id": f"{agrupador}-{row['cpf']}",
            "agrupador": agrupador,
            "tipoPessoa": "FISICA",
            "nome": re.sub(r'\d+','',row['nome'].upper()),
            "cpf": row['cpf'],
            "dataNascimento": data_nascimento,
            "tipo": row['tipo'],
            "enderecos": [
                {
                    "cep": row['cep'],
                    "logradouro": re.sub(r'\d+','',row['endereco'].upper()),
                    "bairro": re.sub(r'\d+','',row['bairro'].upper()),
                    "cidade": re.sub(r'\d+','',row['cidade'].upper()),
                    "numero": row['numero'],
                    "uf": re.sub(r'\d+','',row['estado'].upper())
                }
            ],
            "emails": [
                {
                    "email": row['email']
                }
            ],
            "telefones": [
                {
                    "tipo": "CELULAR",
                    "ddd": ddd,
                    "telefone": telefone
                }
            ],
            "informacoesAdicionais": [
                {
                    "campo": "cpf_aluno",
                    "linha": 1,
                    "coluna": 1,
                    "valor": row['cpf']
                },
                {
                    "campo": "registro_aluno",
                    "linha": 1,
                    "coluna": 1,
                    "valor": row['ra']
                },
                {
                    "campo": "nome_aluno",
                    "linha": 1,
                    "coluna": 1,
                    "valor": re.sub(r'\d+','',row['nome'].upper())
                }
            ]
        }
        json_list.append(json_obj)
    return json_list

# %%
transformar_em_json(lists[0])
# Out:
# [{'id': 'usp-14538854042',
#   'agrupador': 'usp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'ANA SARAH LUNA NUNES',
#   'cpf': '14538854042',
#   'dataNascimento': '07/06/1985',
#   'tipo': 'I',
#   'enderecos': [{'cep': '78028-505',
#     'logradouro': 'AVENIDA FLORIANÓPOLIS',
#     'bairro': 'CIDADE VERDE',
#     'cidade': 'CUIABÁ',
#     'numero': 807,
#     'uf': 'MT'}],
#   'emails': [{'email': 'ana_nunes@live.dk'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '65', 'telefone': '989398957'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '14538854042'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 274405},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'ANA SARAH LUNA NUNES'}]},
#  {'id': 'ufba-74686320909',
#   'agrupador': 'ufba',
#   'tipoPessoa': 'FISICA',
#   'nome': 'BENEDITA RAIMUNDA LORENA REZENDE',
#   'cpf': '74686320909',
#   'dataNascimento': '14/02/2001',
#   'tipo': 'I',
#   'enderecos': [{'cep': '87309-710',
#     'logradouro': 'RUA NELSON BEHRENS',
#     'bairro': 'JARDIM SILVANA',
#     'cidade': 'CAMPO MOURÃO',
#     'numero': 382,
#     'uf': 'PR'}],
#   'emails': [{'email': 'benedita_raimunda_rezende@eletrotex.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '44', 'telefone': '999201842'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '74686320909'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 720462},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'BENEDITA RAIMUNDA LORENA REZENDE'}]},
#  {'id': 'usp-91450681603',
#   'agrupador': 'usp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'STELLA ISABELLE DA CONCEIÇÃO',
#   'cpf': '91450681603',
#   'dataNascimento': '10/03/1994',
#   'tipo': 'I',
#   'enderecos': [{'cep': '11095-906',
#     'logradouro': 'RUA AUGUSTO SCARABOTO, S/N',
#     'bairro': 'ALEMOA',
#     'cidade': 'SANTOS',
#     'numero': 277,
#     'uf': 'SP'}],
#   'emails': [{'email': 'stella-daconceicao92@arbitral.com'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '13', 'telefone': '982658773'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '91450681603'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 882979},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'STELLA ISABELLE DA CONCEIÇÃO'}]},
#  {'id': 'unicamp-18055390193',
#   'agrupador': 'unicamp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'FÁBIO JULIO THEO RODRIGUES',
#   'cpf': '18055390193',
#   'dataNascimento': '08/01/1993',
#   'tipo': 'I',
#   'enderecos': [{'cep': '59604-155',
#     'logradouro': 'RUA CORONEL FAUSTO',
#     'bairro': 'LAGOA DO MATO',
#     'cidade': 'MOSSORÓ',
#     'numero': 137,
#     'uf': 'RN'}],
#   'emails': [{'email': 'fabio_rodrigues@soupelli.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '84', 'telefone': '986066462'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '18055390193'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 504901},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'FÁBIO JULIO THEO RODRIGUES'}]},
#  {'id': 'usp-54231533601',
#   'agrupador': 'usp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'RAQUEL FLÁVIA LUZIA CAMPOS',
#   'cpf': '54231533601',
#   'dataNascimento': '08/02/1988',
#   'tipo': 'I',
#   'enderecos': [{'cep': '53650-180',
#     'logradouro': 'RUA SUIÇA',
#     'bairro': 'BELA VISTA',
#     'cidade': 'IGARASSU',
#     'numero': 446,
#     'uf': 'PE'}],
#   'emails': [{'email': 'raquel.flavia.campos@infortec.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '81', 'telefone': '997622419'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '54231533601'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 657179},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'RAQUEL FLÁVIA LUZIA CAMPOS'}]},
#  {'id': 'usp-46652259400',
#   'agrupador': 'usp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'CAROLINA LUZIA PINTO',
#   'cpf': '46652259400',
#   'dataNascimento': '16/01/1980',
#   'tipo': 'I',
#   'enderecos': [{'cep': '09134-690',
#     'logradouro': 'RUA CATITU',
#     'bairro': 'CIDADE RECREIO DA BORDA DO CAMPO',
#     'cidade': 'SANTO ANDRÉ',
#     'numero': 244,
#     'uf': 'SP'}],
#   'emails': [{'email': 'carolina.luzia.pinto@ceviu.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '11', 'telefone': '995337515'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '46652259400'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 586615},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'CAROLINA LUZIA PINTO'}]},
#  {'id': 'ufba-67261458104',
#   'agrupador': 'ufba',
#   'tipoPessoa': 'FISICA',
#   'nome': 'GABRIELA KAMILLY FERNANDES',
#   'cpf': '67261458104',
#   'dataNascimento': '03/06/1981',
#   'tipo': 'I',
#   'enderecos': [{'cep': '41345-240',
#     'logradouro': 'CAMINHO -SETOR ',
#     'bairro': 'CAJAZEIRAS',
#     'cidade': 'SALVADOR',
#     'numero': 605,
#     'uf': 'BA'}],
#   'emails': [{'email': 'gabriela_kamilly_fernandes@compecia.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '71', 'telefone': '995243132'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '67261458104'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 716203},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'GABRIELA KAMILLY FERNANDES'}]},
#  {'id': 'unicamp-76213854991',
#   'agrupador': 'unicamp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'JUAN THEO YURI ALMEIDA',
#   'cpf': '76213854991',
#   'dataNascimento': '26/05/1990',
#   'tipo': 'I',
#   'enderecos': [{'cep': '71591-350',
#     'logradouro': 'QUADRA QUADRA ',
#     'bairro': 'SÃO CAETANO',
#     'cidade': 'ITABUNA',
#     'numero': 131,
#     'uf': 'BA'}],
#   'emails': [{'email': 'juan_theo_almeida@cppcoder.com'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '61', 'telefone': '989708388'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '76213854991'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 434495},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'JUAN THEO YURI ALMEIDA'}]},
#  {'id': 'unicamp-41402042906',
#   'agrupador': 'unicamp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'ANDRÉ GUSTAVO GALVÃO',
#   'cpf': '41402042906',
#   'dataNascimento': '02/05/1952',
#   'tipo': 'I',
#   'enderecos': [{'cep': '74993-530',
#     'logradouro': 'AVENIDA MARIA ELIAS LISBOA SANTOS',
#     'bairro': 'JARDIM HELIAN',
#     'cidade': 'SÃO PAULO',
#     'numero': 385,
#     'uf': 'SP'}],
#   'emails': [{'email': 'andre.gustavo.galvao@torah.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '62', 'telefone': '999665332'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '41402042906'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 991884},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'ANDRÉ GUSTAVO GALVÃO'}]},
#  {'id': 'unicamp-58367221028',
#   'agrupador': 'unicamp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'PEDRO RENATO THOMAS SALES',
#   'cpf': '58367221028',
#   'dataNascimento': '15/01/1993',
#   'tipo': 'I',
#   'enderecos': [{'cep': '08265-070',
#     'logradouro': 'RUA GUILHERME DA CRUZ',
#     'bairro': 'PARQUE INDUSTRIAL VICE-PRESIDENTE JOSÉ ALENCAR',
#     'cidade': 'APARECIDA DE GOIÂNIA',
#     'numero': 718,
#     'uf': 'GO'}],
#   'emails': [{'email': 'pedro.renato.sales@rodrigofranco.com'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '11', 'telefone': '987589786'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '58367221028'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 133682},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'PEDRO RENATO THOMAS SALES'}]},
#  {'id': 'unicamp-74154779109',
#   'agrupador': 'unicamp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'GAEL ENRICO THEO BAPTISTA',
#   'cpf': '74154779109',
#   'dataNascimento': '13/03/1998',
#   'tipo': 'I',
#   'enderecos': [{'cep': '45607-148',
#     'logradouro': 'ª TRAVESSA SANTO ANTONIO',
#     'bairro': 'DEL LAGO I (ITAPOÃ)',
#     'cidade': 'BRASÍLIA',
#     'numero': 930,
#     'uf': 'DF'}],
#   'emails': [{'email': 'gael_baptista@mcpsolucoesgraficas.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '73', 'telefone': '985284335'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '74154779109'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 364479},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'GAEL ENRICO THEO BAPTISTA'}]},
#  {'id': 'ufrj-47401084961',
#   'agrupador': 'ufrj',
#   'tipoPessoa': 'FISICA',
#   'nome': 'HEITOR FERNANDO MURILO RAMOS',
#   'cpf': '47401084961',
#   'dataNascimento': '01/01/2000',
#   'tipo': 'I',
#   'enderecos': [{'cep': '99042-085',
#     'logradouro': 'RUA ANTÔNIO CESAR',
#     'bairro': 'VERA CRUZ',
#     'cidade': 'PASSO FUNDO',
#     'numero': 279,
#     'uf': 'RS'}],
#   'emails': [{'email': 'heitorfernandoramos@live.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '54', 'telefone': '984296580'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '47401084961'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 786470},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'HEITOR FERNANDO MURILO RAMOS'}]},
#  {'id': 'ufrj-29173074390',
#   'agrupador': 'ufrj',
#   'tipoPessoa': 'FISICA',
#   'nome': 'ELISA RAYSSA BIANCA DUARTE',
#   'cpf': '29173074390',
#   'dataNascimento': '13/05/2000',
#   'tipo': 'I',
#   'enderecos': [{'cep': '79015-370',
#     'logradouro': 'RUA LUÍZ RONCOLATTO',
#     'bairro': 'JARDIM PRESIDENTE',
#     'cidade': 'CAMPO GRANDE',
#     'numero': 470,
#     'uf': 'MS'}],
#   'emails': [{'email': 'elisa.rayssa.duarte@powerblade.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '67', 'telefone': '985918693'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '29173074390'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 141017},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'ELISA RAYSSA BIANCA DUARTE'}]},
#  {'id': 'ufrj-04012272195',
#   'agrupador': 'ufrj',
#   'tipoPessoa': 'FISICA',
#   'nome': 'BRUNO ANDERSON ENZO DA MATA',
#   'cpf': '04012272195',
#   'dataNascimento': '04/02/1973',
#   'tipo': 'I',
#   'enderecos': [{'cep': '64052-150',
#     'logradouro': 'RUA CORONEL BELISÁRIO DA CUNHA',
#     'bairro': 'SÃO CRISTÓVÃO',
#     'cidade': 'TERESINA',
#     'numero': 656,
#     'uf': 'PI'}],
#   'emails': [{'email': 'bruno_damata@aerobravo.com.br'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '86', 'telefone': '983162103'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '04012272195'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 780593},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'BRUNO ANDERSON ENZO DA MATA'}]},
#  {'id': 'ufrj-46547901360',
#   'agrupador': 'ufrj',
#   'tipoPessoa': 'FISICA',
#   'nome': 'ELIANE SARAH SILVEIRA',
#   'cpf': '46547901360',
#   'dataNascimento': '21/01/1982',
#   'tipo': 'I',
#   'enderecos': [{'cep': '61608-255',
#     'logradouro': 'RUA CACIQUE ALBERTO',
#     'bairro': 'PARQUE SOLEDADE',
#     'cidade': 'CAUCAIA',
#     'numero': 706,
#     'uf': 'CE'}],
#   'emails': [{'email': 'elianesarahsilveira@comdados.com'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '85', 'telefone': '994833659'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '46547901360'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 703193},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'ELIANE SARAH SILVEIRA'}]},
#  {'id': 'usp-91450681603',
#   'agrupador': 'usp',
#   'tipoPessoa': 'FISICA',
#   'nome': 'STELLA ISABELLE DA CONCEIÇÃO',
#   'cpf': '91450681603',
#   'dataNascimento': '10/03/1994',
#   'tipo': 'I',
#   'enderecos': [{'cep': '11095-906',
#     'logradouro': 'RUA AUGUSTO SCARABOTO, S/N',
#     'bairro': 'ALEMOA',
#     'cidade': 'SANTOS',
#     'numero': 277,
#     'uf': 'SP'}],
#   'emails': [{'email': 'stella-daconceicao92@arbitral.com'}],
#   'telefones': [{'tipo': 'CELULAR', 'ddd': '13', 'telefone': '982658773'}],
#   'informacoesAdicionais': [{'campo': 'cpf_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': '91450681603'},
#    {'campo': 'registro_aluno', 'linha': 1, 'coluna': 1, 'valor': 882979},
#    {'campo': 'nome_aluno',
#     'linha': 1,
#     'coluna': 1,
#     'valor': 'STELLA ISABELLE DA CONCEIÇÃO'}]}]

# %%
import pandas as pd
import json
import re
from datetime import datetime
import requests
import os
from typing import Any
import time

dados = "dados.xlsx"
sistema = "sistema.xlsx"

class DataService: 
    def __init__(self, dados_path, sistema_path) -> None: 
        self.dados_path =  dados_path
        self.sistema_path = sistema_path
        
    def get_data(self) -> list:
        
        dfs = []
        
        sources = [self.dados_path, self.sistema_path]
        for source in sources:
            file_name, file_extension = os.path.splitext(source)
            
            try: 
                if file_name == "dados":
                    df_dados = pd.read_excel(source)
                    dfs.append(df_dados)
                else:
                    df_sistema = pd.read_excel(source)
                    dfs.append(df_sistema)
            except TypeError:
                print(f"{file_extension} is not a valid extension.")
                
        return dfs
    
    def __call__(self) -> list:
        return self.get_data()
    
class RowValidator:
    def __init__(self, data):
        self.data = data
        
    def validate_cpf(self):
        cpf = self.data.get('cpf')
        cpf = re.sub(r'\D', '', cpf)
        if len(cpf) != 11 or cpf == cpf[0] * 11:
            return False
        for i in range(9, 11):
            cpf_sum = sum(int(cpf[num]) * (i + 1 - num) for num in range(i))
            key_value = (cpf_sum * 10 % 11) % 10
            if key_value != int(cpf[i]):
                return False
        return True

    def validate_name(self):
        name = self.data.get('nome')
        return len(name.split()) >= 2

    def validate_birthday_and_age(self):
        birthday = self.data.get('data_nasc')
        today = datetime.today()
        
        if isinstance(birthday, datetime):
            birth_date = birthday
        else:
            formats = ['%Y-%m-%d', '%d/%m/%Y']
            birth_date = None
            for valid_format in formats:
                try:
                    birth_date = datetime.strptime(birthday, valid_format)
                    break
                except ValueError:
                    continue
            
            if birth_date is None:
                return False 

        age = (today - birth_date).days / 365.25
        return age >= 17

    def validate_email(self):
        email = self.data.get('email', "")
        regex = r'^\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
        return re.match(regex, email) is not None

    def validate_phone(self):
        phone_number = self.data.get('celular')
        regex = r'^\([1-9]{2}\) (?:[2-8]|9[0-9])[0-9]{3}\-[0-9]{4}$'  
        return re.match(regex, phone_number) is not None

    def validate_cep(self):
        cep = self.data.get('cep')
        url = f"https://viacep.com.br/ws/{cep}/json/"
        response = requests.get(url)
        if response.status_code == 200:
            dados_cep = response.json()
            if "erro" not in dados_cep:
                return True, dados_cep
        return False, None

    def validar_cliente(self):
        resultado = {
            'cpf_validation': self.validate_cpf(),
            'name_validation': self.validate_name(),
            'birthdate_and_age_validation': self.validate_birthday_and_age(),
            'email_validation': self.validate_email(),
            'phone_validation': self.validate_phone(),
            'cep_validation': self.validate_cep()[0]
        }
        return resultado

    def pipeline(self):
        validacoes = self.validar_cliente()
        return validacoes

    def __call__(self): 
        return self.pipeline()

class ValidatorService:
    def __init__(self,dataframe) -> None:
        self.dataframe = dataframe
    
    def normalize_dataframe(self) -> pd.DataFrame:
        columns = {"NOME" : "nome",
            "CPF" : "cpf",
            "Data de Nascimento" : "data_nasc",
            "Email" : "email",
            "CEP" : "cep",
            "Endereço" : "endereco",
            "Numero" : "numero",
            "Bairro" : "bairro",
            "Cidade" : "cidade",
            "Estado" : "estado",
            "Telefone" : "celular",
            "RA" : "ra",
            "Curso" : "curso",
            "Faculdade" : "faculdade"
            }
            
        normalized_dataframe = self.dataframe.rename(columns = columns)
        return normalized_dataframe
    
    def create_valid_and_detached_list(self, dataframe: pd.DataFrame) -> Any:
        valid_list = []
        detached_list = []

        for _, line in dataframe.iterrows():
            l = line.to_dict()
            
            row_validator = RowValidator(l)
            
            is_valid = row_validator()
            
            if all(condition == True for condition in is_valid.values()):
                valid_list.append(l)

            else: 
                detach_reasons = [key for key, value in is_valid.items() if not value]
                l["detach_reason"] = detach_reasons
                detached_list.append(l)
                
        print(valid_list)
        print(detached_list)
                
        complete_lists = [valid_list, detached_list]
                
        return complete_lists
    
    def pipeline(self) -> Any:
        df = self.normalize_dataframe()
        complete_lists = self.create_valid_and_detached_list(dataframe= df)
        print(complete_lists)
        return complete_lists
    
    def __call__(self) -> Any:
        return self.pipeline()
        
class UpdateOrDuplicatedChecker:
    def __init__(self, lists : list, df_system : pd.DataFrame) -> None:
        self.valid, self.detached = lists
        self.df_system = df_system
    
    def check_update_needed(self):
        print(self.valid)
        print(self.detached)
        df_detached = pd.DataFrame(self.detached)
        df_valid = pd.DataFrame(self.valid)
        df_system = self.df_system.copy()
        df_valid['cpf'] = df_valid['cpf'].str.replace(r'\D', '', regex=True)
        df_system['cpf'] = df_system['cpf'].str.replace(r'\D', '', regex=True)
        
        common_cpf = set(df_valid['cpf']).intersection(set(df_system['cpf']))
        
        removed_from_valid = []
        
        for cpf in common_cpf:
            df_valid_row = df_valid[df_valid['cpf'] == cpf].drop(columns='cpf').reset_index(drop = True)
            df_system_row = df_system[df_system['cpf'] == cpf].drop(columns='cpf').reset_index(drop = True)
            
            common_cols = df_valid_row.columns.intersection(df_system_row.columns)
            
            print(common_cols)
            
            df_valid_row_common = df_valid_row[common_cols]
            df_system_row_common = df_system_row[common_cols]
            
            print(df_valid_row_common)
            print(df_system_row_common)
            
            if df_valid_row_common.equals(df_system_row_common):
                valid_row_dict = df_valid[df_valid['cpf'] == cpf].to_dict('records')[0]
                valid_row_dict['detach_reason'] = ['update_validation']
                removed_from_valid.append(valid_row_dict)
                df_valid = df_valid[df_valid['cpf'] != cpf]

            else:
                df_valid.loc[df_valid['cpf'] == cpf, 'tipo'] = 'A'
                    
        df_detached = pd.concat([df_detached, pd.DataFrame(removed_from_valid)], ignore_index=True)
                
        df_valid.loc[~df_valid['cpf'].isin(df_system['cpf']), 'tipo'] = 'I'
        
        df_detached.reset_index(drop=True, inplace=True)
        
        return [df_valid, df_detached]
    
    def __call__(self) -> Any:
        return self.check_update_needed()
        
def transformar_em_json(df):
    json_list = []
    for _, row in df.iterrows():
        agrupador = row['faculdade'].lower()  
        ddd, telefone = row['celular'][1:3], row['celular'][5:].replace('-', '')
        
        if isinstance(row['data_nasc'], datetime):
            data_nascimento = row['data_nasc'].strftime('%d/%m/%Y')
        else:
            data_nascimento = row['data_nasc']
        
        json_obj = {
            "id": f"{agrupador}-{row['cpf']}",
            "agrupador": agrupador,
            "tipoPessoa": "FISICA",
            "nome": re.sub(r'\d+','',row['nome'].upper()),
            "cpf": row['cpf'],
            "dataNascimento": data_nascimento,
            "tipo": row['tipo'],
            "enderecos": [
                {
                    "cep": row['cep'],
                    "logradouro": re.sub(r'\d+','',row['endereco'].upper()),
                    "bairro": re.sub(r'\d+','',row['bairro'].upper()),
                    "cidade": re.sub(r'\d+','',row['cidade'].upper()),
                    "numero": str(row['numero']),
                    "uf": re.sub(r'\d+','',row['estado'].upper())
                }
            ],
            "emails": [
                {
                    "email": row['email']
                }
            ],
            "telefones": [
                {
                    "tipo": "CELULAR",
                    "ddd": ddd,
                    "telefone": telefone
                }
            ],
            "informacoesAdicionais": [
                {
                    "campo": "cpf_aluno",
                    "linha": "1",
                    "coluna": "1",
                    "valor": row['cpf']
                },
                {
                    "campo": "registro_aluno",
                    "linha": "1",
                    "coluna": "1",
                    "valor": str(row['ra'])
                },
                {
                    "campo": "nome_aluno",
                    "linha": "1",
                    "coluna": "1",
                    "valor": re.sub(r'\d+','',row['nome'].upper())
                }
            ]
        }
        json_list.append(json_obj)
    return json_list

get_data = DataService(dados,sistema)
data = get_data()

get_validated_data = ValidatorService(dataframe = data[0])
validated_data = get_validated_data()

update_or_duplicate = UpdateOrDuplicatedChecker(validated_data, data[1])
separated_data = update_or_duplicate()

data_json = transformar_em_json(separated_data[0])
c_time = time.strftime("%Y%m%d")
detached_data_filename = f"dados_descartados-{c_time}.xlsx"
datajson_filename = f"dados-{c_time}.json"
detached_data = separated_data[1].to_excel(detached_data_filename)

with open(datajson_filename, 'w', encoding='utf-8') as json_file:
    json.dump(data_json, json_file, ensure_ascii=False, indent=4)
# Out:
# [{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade' ...
# [{'nome': 'Antônia Esther Vitória Cardoso', 'cpf': '564.798.046-52', 'data_nasc': datetime.datetime(1984, 2, 6, 0, 0), 'email': 'antonia-cardoso92@suzano.com.br', 'cep': '69041-380', 'endereco': 'Rua Praia Farol da Barra', 'numero': 935, 'bairro': 'Tarumã', 'cidade': 'Manaus', 'estado': 'AM', 'celular': '(92) 98772-3758', 'ra': 1077822, 'curso': 'Direito', 'faculdade': 'UNICAMP', 'detach_reason': ['cpf_validation']}, {'nome': 'Mariane Maya Stella Novaes', 'cpf': '972.063.648-73', 'data_nasc': datetime.datetime(1996, 3, 13, 0, 0), 'email': 'mariane_novaes@pq.cnpq.br', 'cep': '40081-320', 'endereco': 'Travessa Hugo Wilson', 'numero': 431, 'bairro': 'Vitória', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99779-9889', 'ra': 649062, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Luzia Flávia Bernardes', 'cpf': '669.222.518-3', 'data_nasc': '16/03/1968', 'email': 'luziaflaviabernardes@gimail.com', 'cep': '49080-230', 'endereco': 'Praça Franklin Delano Roosevelt', 'numero': 789, 'bairro': 'América', 'cidade': 'Aracaju', 'estado': 'SE', 'celular': '(79) 98665-1272', 'ra': 94708, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Rosa Nair Dias', 'cpf': '48.923.212-49', 'data_nasc': datetime.datetime(2004, 5, 7, 0, 0), 'email': 'rosa-dias84@myself.com', 'cep': '58030-070', 'endereco': 'Avenida Santa Catarina', 'numero': 690, 'bairro': 'Estados', 'cidade': 'João Pessoa', 'estado': 'PB', 'celular': '(83) 99964-8228', 'ra': 373373, 'curso': 'Engenharia', 'faculdade': 'UFBA', 'detach_reason': ['cpf_validation']}]
# [[{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade ...
# [{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade' ...
# [{'nome': 'Antônia Esther Vitória Cardoso', 'cpf': '564.798.046-52', 'data_nasc': datetime.datetime(1984, 2, 6, 0, 0), 'email': 'antonia-cardoso92@suzano.com.br', 'cep': '69041-380', 'endereco': 'Rua Praia Farol da Barra', 'numero': 935, 'bairro': 'Tarumã', 'cidade': 'Manaus', 'estado': 'AM', 'celular': '(92) 98772-3758', 'ra': 1077822, 'curso': 'Direito', 'faculdade': 'UNICAMP', 'detach_reason': ['cpf_validation']}, {'nome': 'Mariane Maya Stella Novaes', 'cpf': '972.063.648-73', 'data_nasc': datetime.datetime(1996, 3, 13, 0, 0), 'email': 'mariane_novaes@pq.cnpq.br', 'cep': '40081-320', 'endereco': 'Travessa Hugo Wilson', 'numero': 431, 'bairro': 'Vitória', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99779-9889', 'ra': 649062, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Luzia Flávia Bernardes', 'cpf': '669.222.518-3', 'data_nasc': '16/03/1968', 'email': 'luziaflaviabernardes@gimail.com', 'cep': '49080-230', 'endereco': 'Praça Franklin Delano Roosevelt', 'numero': 789, 'bairro': 'América', 'cidade': 'Aracaju', 'estado': 'SE', 'celular': '(79) 98665-1272', 'ra': 94708, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Rosa Nair Dias', 'cpf': '48.923.212-49', 'data_nasc': datetime.datetime(2004, 5, 7, 0, 0), 'email': 'rosa-dias84@myself.com', 'cep': '58030-070', 'endereco': 'Avenida Santa Catarina', 'numero': 690, 'bairro': 'Estados', 'cidade': 'João Pessoa', 'estado': 'PB', 'celular': '(83) 99964-8228', 'ra': 373373, 'curso': 'Engenharia', 'faculdade': 'UFBA', 'detach_reason': ['cpf_validation']}]
# Index(['nome', 'data_nasc', 'email', 'cep', 'endereco', 'numero', 'bairro',
#        'cidade', 'estado', 'celular'],
#       dtype='object')
#                    nome            data_nasc  \
# 0  César Roberto Castro  1988-01-09 00:00:00
#
#                                   email        cep                endereco  \
# 0  cesar-castro95@vectrausinagem.com.br  86191-470  Rua Reinaldo Resquetti
#
#    numero            bairro cidade estado          celular
# 0     165  Jardim Boa Vista  Cambé     PR  (43) 99231-1491
#                    nome            data_nasc  \
# 0  César Roberto Castro  1988-01-09 00:00:00
#
#                                   email        cep                endereco  \
# 0  cesar-castro95@vectrausinagem.com.br  86191-470  Rua Reinaldo Resquetti
#
#    numero            bairro cidade estado          celular
# 0     165  Jardim Boa Vista  Cambé     PR  (43) 99231-1491

# %%
separated_data[1]
# Out:
#                              nome             cpf            data_nasc  \
# 0  Antônia Esther Vitória Cardoso  564.798.046-52  1984-02-06 00:00:00
# 1      Mariane Maya Stella Novaes  972.063.648-73  1996-03-13 00:00:00
# 2          Luzia Flávia Bernardes   669.222.518-3           16/03/1968
# 3                  Rosa Nair Dias   48.923.212-49  2004-05-07 00:00:00
# 4            César Roberto Castro     56862426745  1988-01-09 00:00:00
#
#                                   email        cep  \
# 0       antonia-cardoso92@suzano.com.br  69041-380
# 1             mariane_novaes@pq.cnpq.br  40081-320
# 2       luziaflaviabernardes@gimail.com  49080-230
# 3                rosa-dias84@myself.com  58030-070
# 4  cesar-castro95@vectrausinagem.com.br  86191-470
#
#                           endereco  numero            bairro       cidade  \
# 0         Rua Praia Farol da Barra     935            Tarumã       Manaus
# 1             Travessa Hugo Wilson     431           Vitória     Salvador
# 2  Praça Franklin Delano Roosevelt     789           América      Aracaju
# 3           Avenida Santa Catarina     690           Estados  João Pessoa
# 4           Rua Reinaldo Resquetti     165  Jardim Boa Vista        Cambé
#
#   estado          celular       ra       curso faculdade        detach_reason
# 0     AM  (92) 98772-3758  1077822     Direito   UNICAMP     [cpf_validation]
# 1     BA  (71) 99779-9889   649062  Engenharia      UFRJ     [cpf_validation]
# 2     SE  (79) 98665-1272    94708  Engenharia      UFRJ     [cpf_validation]
# 3     PB  (83) 99964-8228   373373  Engenharia      UFBA     [cpf_validation]
# 4     PR  (43) 99231-1491   533964      Letras      UFPR  [update_validation]

# %%
import pandas as pd
import json
import re
from datetime import datetime
import requests
import os
from typing import Any
import time

dados = "dados.xlsx"
sistema = "sistema.xlsx"

class DataService: 
    def __init__(self, dados_path, sistema_path) -> None: 
        self.dados_path =  dados_path
        self.sistema_path = sistema_path
        
    def get_data(self) -> list:
        
        dfs = []
        
        sources = [self.dados_path, self.sistema_path]
        for source in sources:
            file_name, file_extension = os.path.splitext(source)
            
            try: 
                if file_name == "dados":
                    df_dados = pd.read_excel(source)
                    dfs.append(df_dados)
                else:
                    df_sistema = pd.read_excel(source)
                    dfs.append(df_sistema)
            except TypeError:
                print(f"{file_extension} is not a valid extension.")
                
        return dfs
    
    def __call__(self) -> list:
        return self.get_data()
    
class RowValidator:
    def __init__(self, data):
        self.data = data
        
    def validate_cpf(self):
        cpf = self.data.get('cpf')
        cpf = re.sub(r'\D', '', cpf)
        if len(cpf) != 11 or cpf == cpf[0] * 11:
            return False
        for i in range(9, 11):
            cpf_sum = sum(int(cpf[num]) * (i + 1 - num) for num in range(i))
            key_value = (cpf_sum * 10 % 11) % 10
            if key_value != int(cpf[i]):
                return False
        return True

    def validate_name(self):
        name = self.data.get('nome')
        return len(name.split()) >= 2

    def validate_birthday_and_age(self):
        birthday = self.data.get('data_nasc')
        today = datetime.today()
        
        if isinstance(birthday, datetime):
            birth_date = birthday
        else:
            formats = ['%Y-%m-%d', '%d/%m/%Y']
            birth_date = None
            for valid_format in formats:
                try:
                    birth_date = datetime.strptime(birthday, valid_format)
                    break
                except ValueError:
                    continue
            
            if birth_date is None:
                return False 

        age = (today - birth_date).days / 365.25
        return age >= 17

    def validate_email(self):
        email = self.data.get('email', "")
        regex = r'^\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
        return re.match(regex, email) is not None

    def validate_phone(self):
        phone_number = self.data.get('celular')
        regex = r'^\([1-9]{2}\) (?:[2-8]|9[0-9])[0-9]{3}\-[0-9]{4}$'  
        return re.match(regex, phone_number) is not None

    def validate_cep(self):
        cep = self.data.get('cep')
        url = f"https://viacep.com.br/ws/{cep}/json/"
        response = requests.get(url)
        if response.status_code == 200:
            dados_cep = response.json()
            if "erro" not in dados_cep:
                return True, dados_cep
        return False, None

    def validar_cliente(self):
        resultado = {
            'cpf_validation': self.validate_cpf(),
            'name_validation': self.validate_name(),
            'birthdate_and_age_validation': self.validate_birthday_and_age(),
            'email_validation': self.validate_email(),
            'phone_validation': self.validate_phone(),
            'cep_validation': self.validate_cep()[0]
        }
        return resultado

    def pipeline(self):
        validacoes = self.validar_cliente()
        return validacoes

    def __call__(self): 
        return self.pipeline()

class ValidatorService:
    def __init__(self,dataframe) -> None:
        self.dataframe = dataframe
    
    def normalize_dataframe(self) -> pd.DataFrame:
        columns = {"NOME" : "nome",
            "CPF" : "cpf",
            "Data de Nascimento" : "data_nasc",
            "Email" : "email",
            "CEP" : "cep",
            "Endereço" : "endereco",
            "Numero" : "numero",
            "Bairro" : "bairro",
            "Cidade" : "cidade",
            "Estado" : "estado",
            "Telefone" : "celular",
            "RA" : "ra",
            "Curso" : "curso",
            "Faculdade" : "faculdade"
            }
            
        normalized_dataframe = self.dataframe.rename(columns = columns)
        return normalized_dataframe
    
    def create_valid_and_detached_list(self, dataframe: pd.DataFrame) -> Any:
        valid_list = []
        detached_list = []

        for _, line in dataframe.iterrows():
            l = line.to_dict()
            
            row_validator = RowValidator(l)
            
            is_valid = row_validator()
            
            if all(condition == True for condition in is_valid.values()):
                valid_list.append(l)

            else: 
                detach_reasons = [key for key, value in is_valid.items() if not value]
                l["detach_reason"] = detach_reasons
                detached_list.append(l)
                
        print(valid_list)
        print(detached_list)
                
        complete_lists = [valid_list, detached_list]
                
        return complete_lists
    
    def pipeline(self) -> Any:
        df = self.normalize_dataframe()
        complete_lists = self.create_valid_and_detached_list(dataframe= df)
        print(complete_lists)
        return complete_lists
    
    def __call__(self) -> Any:
        return self.pipeline()
        
class UpdateOrDuplicatedChecker:
    def __init__(self, lists : list, df_system : pd.DataFrame) -> None:
        self.valid, self.detached = lists
        self.df_system = df_system
    
    def check_update_needed(self):
        print(self.valid)
        print(self.detached)
        df_detached = pd.DataFrame(self.detached)
        df_valid = pd.DataFrame(self.valid)
        df_system = self.df_system.copy()
        df_valid['cpf'] = df_valid['cpf'].str.replace(r'\D', '', regex=True)
        df_system['cpf'] = df_system['cpf'].str.replace(r'\D', '', regex=True)
        
        common_cpf = set(df_valid['cpf']).intersection(set(df_system['cpf']))
        
        removed_from_valid = []
        
        for cpf in common_cpf:
            df_valid_row = df_valid[df_valid['cpf'] == cpf].drop(columns='cpf').reset_index(drop = True)
            df_system_row = df_system[df_system['cpf'] == cpf].drop(columns='cpf').reset_index(drop = True)
            
            common_cols = df_valid_row.columns.intersection(df_system_row.columns)
            
            print(common_cols)
            
            df_valid_row_common = df_valid_row[common_cols]
            df_system_row_common = df_system_row[common_cols]
            
            print(df_valid_row_common)
            print(df_system_row_common)
            
            if df_valid_row_common.equals(df_system_row_common):
                valid_row_dict = df_valid[df_valid['cpf'] == cpf].to_dict('records')[0]
                valid_row_dict['detach_reason'] = ['update_validation']
                removed_from_valid.append(valid_row_dict)
                df_valid = df_valid[df_valid['cpf'] != cpf]

            else:
                df_valid.loc[df_valid['cpf'] == cpf, 'tipo'] = 'A'
                    
        df_detached = pd.concat([df_detached, pd.DataFrame(removed_from_valid)], ignore_index=True)
                
        df_valid.loc[~df_valid['cpf'].isin(df_system['cpf']), 'tipo'] = 'I'
        
        df_detached.reset_index(drop=True, inplace=True)
        
        return [df_valid, df_detached]
    
    def __call__(self) -> Any:
        return self.check_update_needed()
        
def transformar_em_json(df):
    json_list = []
    for _, row in df.iterrows():
        agrupador = row['faculdade'].lower()  
        ddd, telefone = row['celular'][1:3], row['celular'][5:].replace('-', '')
        
        if isinstance(row['data_nasc'], datetime):
            data_nascimento = row['data_nasc'].strftime('%d/%m/%Y')
        else:
            data_nascimento = row['data_nasc']
        
        json_obj = {
            "id": f"{agrupador}-{row['cpf']}",
            "agrupador": agrupador,
            "tipoPessoa": "FISICA",
            "nome": re.sub(r'\d+','',row['nome'].upper()),
            "cpf": row['cpf'],
            "dataNascimento": data_nascimento,
            "tipo": row['tipo'],
            "enderecos": [
                {
                    "cep": row['cep'],
                    "logradouro": re.sub(r'\d+','',row['endereco'].upper()),
                    "bairro": re.sub(r'\d+','',row['bairro'].upper()),
                    "cidade": re.sub(r'\d+','',row['cidade'].upper()),
                    "numero": str(row['numero']),
                    "uf": re.sub(r'\d+','',row['estado'].upper())
                }
            ],
            "emails": [
                {
                    "email": row['email']
                }
            ],
            "telefones": [
                {
                    "tipo": "CELULAR",
                    "ddd": ddd,
                    "telefone": telefone
                }
            ],
            "informacoesAdicionais": [
                {
                    "campo": "cpf_aluno",
                    "linha": "1",
                    "coluna": "1",
                    "valor": row['cpf']
                },
                {
                    "campo": "registro_aluno",
                    "linha": "1",
                    "coluna": "1",
                    "valor": str(row['ra'])
                },
                {
                    "campo": "nome_aluno",
                    "linha": "1",
                    "coluna": "1",
                    "valor": re.sub(r'\d+','',row['nome'].upper())
                }
            ]
        }
        json_list.append(json_obj)
    return json_list

get_data = DataService(dados,sistema)
data = get_data()

get_validated_data = ValidatorService(dataframe = data[0])
validated_data = get_validated_data()

update_or_duplicate = UpdateOrDuplicatedChecker(validated_data, data[1])
separated_data = update_or_duplicate()

data_json = transformar_em_json(separated_data[0])
c_time = time.strftime("%Y%m%d")
detached_data_filename = f"dados_descartados-{c_time}.xlsx"
datajson_filename = f"dados-{c_time}.json"
separated_data[1]['data_nasc'] = pd.to_datetime(separated_data[1]['data_nasc'], errors='coerce').dt.strftime('%d/%m/%Y')
detached_data = separated_data[1].to_excel(detached_data_filename)

with open(datajson_filename, 'w', encoding='utf-8') as json_file:
    json.dump(data_json, json_file, ensure_ascii=False, indent=4)
# Out:
# [{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade' ...
# [{'nome': 'Antônia Esther Vitória Cardoso', 'cpf': '564.798.046-52', 'data_nasc': datetime.datetime(1984, 2, 6, 0, 0), 'email': 'antonia-cardoso92@suzano.com.br', 'cep': '69041-380', 'endereco': 'Rua Praia Farol da Barra', 'numero': 935, 'bairro': 'Tarumã', 'cidade': 'Manaus', 'estado': 'AM', 'celular': '(92) 98772-3758', 'ra': 1077822, 'curso': 'Direito', 'faculdade': 'UNICAMP', 'detach_reason': ['cpf_validation']}, {'nome': 'Mariane Maya Stella Novaes', 'cpf': '972.063.648-73', 'data_nasc': datetime.datetime(1996, 3, 13, 0, 0), 'email': 'mariane_novaes@pq.cnpq.br', 'cep': '40081-320', 'endereco': 'Travessa Hugo Wilson', 'numero': 431, 'bairro': 'Vitória', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99779-9889', 'ra': 649062, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Luzia Flávia Bernardes', 'cpf': '669.222.518-3', 'data_nasc': '16/03/1968', 'email': 'luziaflaviabernardes@gimail.com', 'cep': '49080-230', 'endereco': 'Praça Franklin Delano Roosevelt', 'numero': 789, 'bairro': 'América', 'cidade': 'Aracaju', 'estado': 'SE', 'celular': '(79) 98665-1272', 'ra': 94708, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Rosa Nair Dias', 'cpf': '48.923.212-49', 'data_nasc': datetime.datetime(2004, 5, 7, 0, 0), 'email': 'rosa-dias84@myself.com', 'cep': '58030-070', 'endereco': 'Avenida Santa Catarina', 'numero': 690, 'bairro': 'Estados', 'cidade': 'João Pessoa', 'estado': 'PB', 'celular': '(83) 99964-8228', 'ra': 373373, 'curso': 'Engenharia', 'faculdade': 'UFBA', 'detach_reason': ['cpf_validation']}]
# [[{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade ...
# [{'nome': 'Ana Sarah Luna Nunes', 'cpf': '145.388.540-42', 'data_nasc': datetime.datetime(1985, 6, 7, 0, 0), 'email': 'ana_nunes@live.dk', 'cep': '78028-505', 'endereco': 'Avenida Florianópolis', 'numero': 807, 'bairro': 'Cidade Verde', 'cidade': 'Cuiabá', 'estado': 'MT', 'celular': '(65) 98939-8957', 'ra': 274405, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Benedita Raimunda Lorena Rezende', 'cpf': '746.863. 209-09', 'data_nasc': '14/02/2001', 'email': 'benedita_raimunda_rezende@eletrotex.com.br', 'cep': '87309-710', 'endereco': 'Rua Nelson Behrens', 'numero': 382, 'bairro': 'Jardim Silvana', 'cidade': 'Campo Mourão', 'estado': 'PR', 'celular': '(44) 99920-1842', 'ra': 720462, 'curso': 'Física', 'faculdade': 'UFBA'}, {'nome': 'Stella Isabelle da Conceição', 'cpf': '914.506.816-03', 'data_nasc': datetime.datetime(1994, 3, 10, 0, 0), 'email': 'stella-daconceicao92@arbitral.com', 'cep': '11095-906', 'endereco': 'Rua Augusto Scaraboto, s/n', 'numero': 277, 'bairro': 'Alemoa', 'cidade': 'Santos', 'estado': 'SP', 'celular': '(13) 98265-8773', 'ra': 882979, 'curso': 'Adiministração ', 'faculdade': 'USP'}, {'nome': 'Fábio Julio Theo Rodrigues', 'cpf': '180.553.901-93', 'data_nasc': '08/01/1993', 'email': 'fabio_rodrigues@soupelli.com.br', 'cep': '59604-155', 'endereco': 'Rua Coronel Fausto', 'numero': 137, 'bairro': 'Lagoa do Mato', 'cidade': 'Mossoró', 'estado': 'RN', 'celular': '(84) 98606-6462', 'ra': 504901, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Raquel Flávia Luzia Campos', 'cpf': '542.315.336-01', 'data_nasc': datetime.datetime(1988, 2, 8, 0, 0), 'email': 'raquel.flavia.campos@infortec.com.br', 'cep': '53650-180', 'endereco': 'Rua Suiça', 'numero': 446, 'bairro': 'Bela Vista', 'cidade': 'Igarassu', 'estado': 'PE', 'celular': '(81) 99762-2419', 'ra': 657179, 'curso': 'Biologia', 'faculdade': 'USP'}, {'nome': 'César Roberto Castro', 'cpf': '568.624.267-45', 'data_nasc': datetime.datetime(1988, 1, 9, 0, 0), 'email': 'cesar-castro95@vectrausinagem.com.br', 'cep': '86191-470', 'endereco': 'Rua Reinaldo Resquetti', 'numero': 165, 'bairro': 'Jardim Boa Vista', 'cidade': 'Cambé', 'estado': 'PR', 'celular': '(43) 99231-1491', 'ra': 533964, 'curso': 'Letras', 'faculdade': 'UFPR'}, {'nome': 'Carolina Luzia Pinto', 'cpf': '466.5 22.594-00', 'data_nasc': '16/01/1980', 'email': 'carolina.luzia.pinto@ceviu.com.br', 'cep': '09134-690', 'endereco': 'Rua Catitu', 'numero': 244, 'bairro': 'Cidade Recreio da Borda do Campo', 'cidade': 'Santo André', 'estado': 'SP', 'celular': '(11) 99533-7515', 'ra': 586615, 'curso': 'Matemática', 'faculdade': 'USP'}, {'nome': 'Gabriela Kamilly Fernandes', 'cpf': '672.614.581-04', 'data_nasc': datetime.datetime(1981, 6, 3, 0, 0), 'email': 'gabriela_kamilly_fernandes@compecia.com.br', 'cep': '41345-240', 'endereco': 'Caminho 17-Setor 04', 'numero': 605, 'bairro': 'Cajazeiras', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99524-3132', 'ra': 716203, 'curso': 'Adiministração ', 'faculdade': 'UFBA'}, {'nome': 'Juan Theo Yuri Almeida', 'cpf': '762.138.549-91', 'data_nasc': '26/05/1990', 'email': 'juan_theo_almeida@cppcoder.com', 'cep': '71591-350', 'endereco': 'Quadra Quadra 40', 'numero': 131, 'bairro': 'São Caetano', 'cidade': 'Itabuna', 'estado': 'BA', 'celular': '(61) 98970-8388', 'ra': 434495, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'André Gustavo Galvão', 'cpf': '414.020.429-06', 'data_nasc': '02/05/1952', 'email': 'andre.gustavo.galvao@torah.com.br', 'cep': '74993-530', 'endereco': 'Avenida Maria Elias Lisboa Santos', 'numero': 385, 'bairro': 'Jardim Helian', 'cidade': 'São Paulo', 'estado': 'SP', 'celular': '(62) 99966-5332', 'ra': 991884, 'curso': 'Direito', 'faculdade': 'UNICAMP'}, {'nome': 'Pedro Renato Thomas Sales', 'cpf': '583.672.210-28', 'data_nasc': '15/01/1993', 'email': 'pedro.renato.sales@rodrigofranco.com', 'cep': '08265-070', 'endereco': 'Rua Guilherme da Cruz', 'numero': 718, 'bairro': 'Parque Industrial Vice-Presidente José Alencar', 'cidade' ...
# [{'nome': 'Antônia Esther Vitória Cardoso', 'cpf': '564.798.046-52', 'data_nasc': datetime.datetime(1984, 2, 6, 0, 0), 'email': 'antonia-cardoso92@suzano.com.br', 'cep': '69041-380', 'endereco': 'Rua Praia Farol da Barra', 'numero': 935, 'bairro': 'Tarumã', 'cidade': 'Manaus', 'estado': 'AM', 'celular': '(92) 98772-3758', 'ra': 1077822, 'curso': 'Direito', 'faculdade': 'UNICAMP', 'detach_reason': ['cpf_validation']}, {'nome': 'Mariane Maya Stella Novaes', 'cpf': '972.063.648-73', 'data_nasc': datetime.datetime(1996, 3, 13, 0, 0), 'email': 'mariane_novaes@pq.cnpq.br', 'cep': '40081-320', 'endereco': 'Travessa Hugo Wilson', 'numero': 431, 'bairro': 'Vitória', 'cidade': 'Salvador', 'estado': 'BA', 'celular': '(71) 99779-9889', 'ra': 649062, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Luzia Flávia Bernardes', 'cpf': '669.222.518-3', 'data_nasc': '16/03/1968', 'email': 'luziaflaviabernardes@gimail.com', 'cep': '49080-230', 'endereco': 'Praça Franklin Delano Roosevelt', 'numero': 789, 'bairro': 'América', 'cidade': 'Aracaju', 'estado': 'SE', 'celular': '(79) 98665-1272', 'ra': 94708, 'curso': 'Engenharia', 'faculdade': 'UFRJ', 'detach_reason': ['cpf_validation']}, {'nome': 'Rosa Nair Dias', 'cpf': '48.923.212-49', 'data_nasc': datetime.datetime(2004, 5, 7, 0, 0), 'email': 'rosa-dias84@myself.com', 'cep': '58030-070', 'endereco': 'Avenida Santa Catarina', 'numero': 690, 'bairro': 'Estados', 'cidade': 'João Pessoa', 'estado': 'PB', 'celular': '(83) 99964-8228', 'ra': 373373, 'curso': 'Engenharia', 'faculdade': 'UFBA', 'detach_reason': ['cpf_validation']}]
# Index(['nome', 'data_nasc', 'email', 'cep', 'endereco', 'numero', 'bairro',
#        'cidade', 'estado', 'celular'],
#       dtype='object')
#                    nome            data_nasc  \
# 0  César Roberto Castro  1988-01-09 00:00:00
#
#                                   email        cep                endereco  \
# 0  cesar-castro95@vectrausinagem.com.br  86191-470  Rua Reinaldo Resquetti
#
#    numero            bairro cidade estado          celular
# 0     165  Jardim Boa Vista  Cambé     PR  (43) 99231-1491
#                    nome            data_nasc  \
# 0  César Roberto Castro  1988-01-09 00:00:00
#
#                                   email        cep                endereco  \
# 0  cesar-castro95@vectrausinagem.com.br  86191-470  Rua Reinaldo Resquetti
#
#    numero            bairro cidade estado          celular
# 0     165  Jardim Boa Vista  Cambé     PR  (43) 99231-1491
